# %%
#wap to calculte the price of a movie ticket
print("*********Wel Come********")
print("________HarryWorks_______")
age = int(input("Enter you Age to get a Discount: "))
if age < 18:
    print(f"Your ticket price is Rs.108")
elif age >=18 and age <=60:
    print(f"Your ticket price is Rs.450")
if age > 60:
    print(f"Your ticket price is RS.150")
# Out:
# *********Wel Come********
# ________HarryWorks_______
# Enter you Age to get a Discount:  123
# Your ticket price is RS.150
