# %%
#wap to generate a multiplication table asking a numver from user
print("*******MULIPLICATION TABLE********")
num = int(input("Enter the number to generate its multiplication table: "))
for x in range(1,11):
    print(f"{num} * {x} = ",num * x)
# Out:
# *******MULIPLICATION TABLE********
# Enter the number to generate its multiplication table:  2
# 2 * 1 =  2
# 2 * 2 =  4
# 2 * 3 =  6
# 2 * 4 =  8
# 2 * 5 =  10
# 2 * 6 =  12
# 2 * 7 =  14
# 2 * 8 =  16
# 2 * 9 =  18
# 2 * 10 =  20
