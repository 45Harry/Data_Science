# %%
#Wap to seperate the bill 
print("*****Bill Splitter******")
num_of_people = int(input("Enter the total number of People"))
total_bill_amount = int(input("Enter the total Bill Amount"))
amountForEachPeople = total_bill_amount/num_of_people
print(f"Each person have to pay {amountForEachPeople}")
# Out:
# *****Bill Splitter******
# Enter the total number of People 4
# Enter the total Bill Amount 344
# Each person have to pay 86.0
