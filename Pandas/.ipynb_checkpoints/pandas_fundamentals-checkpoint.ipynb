# %%
import pandas as pd

# %%
df = pd.DataFrame(
    {
        "Name":['Braund,Mr. owen Haris',
               'Allen, Mr.William Henry',
               'Bonnell, Miss. Elizabeth',],
        "Age":[22,35,58],
        "Sex":["male","male","female"]
        
    }
)

# %%
df
# Out:
#                        Name  Age     Sex
# 0     Braund,Mr. owen Haris   22    male
# 1   Allen, Mr.William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   58  female

# %%
df["Age"].max()
# Out:
# 58

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   38.333333
# std    18.230012
# min    22.000000
# 25%    28.500000
# 50%    35.000000
# 75%    46.500000
# max    58.000000

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   38.333333
# std    18.230012
# min    22.000000
# 25%    28.500000
# 50%    35.000000
# 75%    46.500000
# max    58.000000

# %%
titanic= pd.read_csv("titanic/tested.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
titanic.to_excel("titanic.xlsx", sheet_name="passengers", index=False)

# %%
exe_titanic = pd.read_excel('titanic.xlsx')

# %%
exe_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
exe_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
ages_sex = titanic[["Age",'Sex']]
ages_sex
# Out:
#       Age     Sex
# 0    34.5    male
# 1    47.0  female
# 2    62.0    male
# 3    27.0    male
# 4    22.0  female
# ..    ...     ...
# 413   NaN    male
# 414  39.0  female
# 415  38.5    male
# 416   NaN    male
# 417   NaN    male
#
# [418 rows x 2 columns]

# %%
titanic['Age'].shape
# Out:
# (418,)

# %%
above_35 = titanic[titanic['Age']>35]
above_35
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 2            894         0       2
# 11           903         0       1
# 13           905         0       2
# 14           906         1       1
# ..           ...       ...     ...
# 404         1296         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
# 415         1307         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1                     Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                            Myles, Mr. Thomas Francis    male  62.0      0
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 13                                Howard, Mr. Benjamin    male  63.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
above_35.shape
# Out:
# (105, 12)

# %%
class_23 = titanic[titanic['Pclass'].isin([2,3])]
class_23.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
age_no_na = titanic[titanic["Age"].notna()]
age_no_na.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
cabin_no_na = titanic[titanic["Cabin"].notna()] #this will print the filtered data that doesnt contain a null value
cabin_no_na
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
cabin_no_na.shape
# Out:
# (91, 12)

# %%
adult_names = titanic.loc[titanic['Age']>35,"Name"]
adult_names.head()
# Out:
# 1                      Wilkes, Mrs. James (Ellen Needs)
# 2                             Myles, Mr. Thomas Francis
# 11                           Jones, Mr. Charles Cresson
# 13                                 Howard, Mr. Benjamin
# 14    Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# Name: Name, dtype: object

# %%
female_names = titanic.loc[titanic['Sex']=='female','Name']
female_names
# Out:
# 1                     Wilkes, Mrs. James (Ellen Needs)
# 4         Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 6                                 Connolly, Miss. Kate
# 8            Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)
#                             ...
# 409                          Peacock, Miss. Treasteall
# 410                             Naughton, Miss. Hannah
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412                     Henriksson, Miss. Jenny Lovisa
# 414                       Oliva y Ocana, Dona. Fermina
# Name: Name, Length: 152, dtype: object

# %%
female_names.shape
# Out:
# (152,)

# %%
titanic.iloc[9:25,2:5]
# Out:
#     Pclass                                               Name     Sex
# 9        3                            Davies, Mr. John Samuel    male
# 10       3                                   Ilieff, Mr. Ylio    male
# 11       1                         Jones, Mr. Charles Cresson    male
# 12       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female
# 13       2                               Howard, Mr. Benjamin    male
# 14       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female
# 15       2      del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female
# 16       2                                  Keane, Mr. Daniel    male
# 17       3                                  Assaf, Mr. Gerios    male
# 18       3                       Ilmakangas, Miss. Ida Livija  female
# 19       3              Assaf Khalil, Mrs. Mariana (Miriam")"  female
# 20       1                             Rothschild, Mr. Martin    male
# ...

# %%
titanic.iloc[0:3,0]= 'test'

# %%
titanic
# Out:
#     PassengerId  Survived  Pclass  \
# 0          test         0       3
# 1          test         1       3
# 2          test         0       2
# 3           895         0       3
# 4           896         1       3
# ..          ...       ...     ...
# 413        1305         0       3
# 414        1306         1       1
# 415        1307         0       3
# 416        1308         0       3
# 417        1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# ...

# %%
import matplotlib.pyplot as plt

# %%
air_quality = pd.read_csv('air_quality_no2.csv',index_col = 0 ,parse_dates = True)
air_quality
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN           21.4             NaN
# 2019-06-20 23:00:00              NaN           24.9             NaN
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 3 columns]

# %%
air_quality.plot()
plt.show()

# %%
air_quality['station_paris'].plot()
plt.show()

# %%
air_quality.plot.scatter(x = 'station_paris',y= 'station_london' , alpha = 1)
plt.show()

# %%
air_quality.plot.box()
plt.show()

# %%
axs = air_quality.plot.area(figsize = (12,4), subplots = True )
plt.show()

# %%
 fig, axs = plt.subplots(figsize=(12, 4))

 air_quality.plot.area(ax=axs)


 axs.set_ylabel("NO$_2$ concentration")


 fig.savefig("no2_concentrations.png")

 plt.show()

# %%
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %%
air_quality['london_mg_per_cubic'] = air_quality['station_london'] * 1.882

# %%
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
#
#                      london_mg_per_cubic
# datetime
# 2019-05-07 02:00:00               43.286
# 2019-05-07 03:00:00               35.758
# 2019-05-07 04:00:00               35.758
# 2019-05-07 05:00:00               30.112
# 2019-05-07 06:00:00                  NaN

# %%
air_quality['ration_pairs_antwerp']= (air_quality["station_paris"]/air_quality['station_antwerp'])
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
#
#                      london_mg_per_cubic  ration_pairs_antwerp
# datetime
# 2019-05-07 02:00:00               43.286                   NaN
# 2019-05-07 03:00:00               35.758              0.495050
# 2019-05-07 04:00:00               35.758              0.615556
# 2019-05-07 05:00:00               30.112                   NaN
# 2019-05-07 06:00:00                  NaN                   NaN

# %%
air_quality_renamed = air_quality.rename(columns={
    'station_antwerp':'BETR801',
    'station_paris':'FRO4O14',
    'station_london':'London_Westminster'
})

# %%
air_quality_renamed.head()
# Out:
#                      BETR801  FRO4O14  London_Westminster  \
# datetime
# 2019-05-07 02:00:00      NaN      NaN                23.0
# 2019-05-07 03:00:00     50.5     25.0                19.0
# 2019-05-07 04:00:00     45.0     27.7                19.0
# 2019-05-07 05:00:00      NaN     50.4                16.0
# 2019-05-07 06:00:00      NaN     61.9                 NaN
#
#                      london_mg_per_cubic  ration_pairs_antwerp
# datetime
# 2019-05-07 02:00:00               43.286                   NaN
# 2019-05-07 03:00:00               35.758              0.495050
# 2019-05-07 04:00:00               35.758              0.615556
# 2019-05-07 05:00:00               30.112                   NaN
# 2019-05-07 06:00:00                  NaN                   NaN

# %%
titanic_df = pd.read_csv('titanic/tested.csv')
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
'Age' in titanic_df.columns
# Out:
# True

# %%
titanic_df['Age'].mean()
# Out:
# 30.272590361445783

# %%
titanic_df[['Age','Fare']].median()
# Out:
# Age     27.0000
# Fare    14.4542
# dtype: float64

# %%
titanic_df[['Age','Fare']].describe()
# Out:
#               Age        Fare
# count  332.000000  417.000000
# mean    30.272590   35.627188
# std     14.181209   55.907576
# min      0.170000    0.000000
# 25%     21.000000    7.895800
# 50%     27.000000   14.454200
# 75%     39.000000   31.500000
# max     76.000000  512.329200

# %%
titanic.agg({
    'Age':['min','max','median','skew'],
    'Fare':['min','max','median','skew']
})
# Out:
#               Age        Fare
# min      0.170000    0.000000
# max     76.000000  512.329200
# median  27.000000   14.454200
# skew     0.457361    3.687213

# %%
titanic[['Sex','Age']].groupby('Sex').mean()  # groupby groups all  male and feamale together and calculte their mean (male and female)
# Out:
#               Age
# Sex
# female  30.272362
# male    30.272732

# %%
titanic.groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    30.272362
# male      30.272732
# Name: Age, dtype: float64

# %%
titanic_df.groupby(['Sex','Pclass'])['Fare'].mean()
# Out:
# Sex     Pclass
# female  1         115.591168
#         2          26.438750
#         3          13.735129
# male    1          75.586551
#         2          20.184654
#         3          11.826350
# Name: Fare, dtype: float64

# %%
titanic_df['Sex'].value_counts()
# Out:
# Sex
# male      266
# female    152
# Name: count, dtype: int64

# %%
titanic_df.groupby('Pclass')['Pclass'].count()
# Out:
# Pclass
# 1    107
# 2     93
# 3    218
# Name: Pclass, dtype: int64

# %%
titanic_df.sort_values(by= 'Age').head()
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 354         1246         1       3  Dean, Miss. Elizabeth Gladys Millvina""
# 201         1093         0       3  Danbom, Master. Gilbert Sigvard Emanuel
# 281         1173         0       3           Peacock, Master. Alfred Edward
# 307         1199         0       3                Aks, Master. Philip Frank
# 250         1142         1       2                    West, Miss. Barbara J
#
#         Sex   Age  SibSp  Parch              Ticket    Fare Cabin Embarked
# 354  female  0.17      1      2           C.A. 2315  20.575   NaN        S
# 201    male  0.33      0      2              347080  14.400   NaN        S
# 281    male  0.75      1      1  SOTON/O.Q. 3101315  13.775   NaN        S
# 307    male  0.83      0      1              392091   9.350   NaN        S
# 250  female  0.92      1      2          C.A. 34651  27.750   NaN        S

# %%
titanic_df.sort_values(by= ['Pclass','Age'],ascending=False).head(6)
# Out:
#      PassengerId  Survived  Pclass  \
# 152         1044         0       3
# 25           917         0       3
# 1            893         1       3
# 19           911         1       3
# 309         1201         1       3
# 134         1026         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 152                          Storey, Mr. Thomas    male  60.5      0      0
# 25                      Robins, Mr. Alexander A    male  50.0      1      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 19        Assaf Khalil, Mrs. Mariana (Miriam")"  female  45.0      0      0
# 309  Hansen, Mrs. Claus Peter (Jennie L Howard)  female  45.0      1      0
# 134                      Dintcheff, Mr. Valtcho    male  43.0      0      0
#
#         Ticket     Fare Cabin Embarked
# 152       3701      NaN   NaN        S
# 25   A/5. 3337  14.5000   NaN        S
# 1       363272   7.0000   NaN        S
# ...

# %%
air_quality = pd.read_csv('air_quality_long.csv',index_col='date.utc',parse_dates=True)
air_quality.head()
# Out:
#                                 city country location parameter  value   unit
# date.utc
# 2019-06-18 06:00:00+00:00  Antwerpen      BE  BETR801      pm25   18.0  µg/m³
# 2019-06-17 08:00:00+00:00  Antwerpen      BE  BETR801      pm25    6.5  µg/m³
# 2019-06-17 07:00:00+00:00  Antwerpen      BE  BETR801      pm25   18.5  µg/m³
# 2019-06-17 06:00:00+00:00  Antwerpen      BE  BETR801      pm25   16.0  µg/m³
# 2019-06-17 05:00:00+00:00  Antwerpen      BE  BETR801      pm25    7.5  µg/m³

# %%
no2 = air_quality[air_quality['parameter']== 'no2']

# %%
no2_subset = no2.sort_index().groupby(['location']).head(10)
no2_subset
# Out:
#                                 city country            location parameter  \
# date.utc
# 2019-04-09 01:00:00+00:00  Antwerpen      BE             BETR801       no2
# 2019-04-09 01:00:00+00:00      Paris      FR             FR04014       no2
# 2019-04-09 02:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 02:00:00+00:00  Antwerpen      BE             BETR801       no2
# 2019-04-09 02:00:00+00:00      Paris      FR             FR04014       no2
# 2019-04-09 03:00:00+00:00  Antwerpen      BE             BETR801       no2
# 2019-04-09 03:00:00+00:00     London      GB  London Westminster       no2
# 2019-04-09 03:00:00+00:00      Paris      FR             FR04014       no2
# 2019-04-09 04:00:00+00:00  Antwerpen      BE             BETR801       no2
# 2019-04-09 04:00:00+00:00      Paris      FR             FR04014       no2
# 2019-04-09 04:00:00+00:00     London      GB  London Westminster       no2
# ...

# %%
no2_subset.pivot(columns='location',values = 'value')
# Out:
# location                   BETR801  FR04014  London Westminster
# date.utc
# 2019-04-09 01:00:00+00:00     22.5     24.4                 NaN
# 2019-04-09 02:00:00+00:00     53.5     27.4                67.0
# 2019-04-09 03:00:00+00:00     54.5     34.2                67.0
# 2019-04-09 04:00:00+00:00     34.5     48.5                41.0
# 2019-04-09 05:00:00+00:00     46.5     59.5                41.0
# 2019-04-09 06:00:00+00:00     50.0     66.9                41.0
# 2019-04-09 07:00:00+00:00     38.5     68.0                45.0
# 2019-04-09 08:00:00+00:00     39.0     69.5                47.0
# 2019-04-09 09:00:00+00:00     35.0     66.5                49.0
# 2019-04-09 10:00:00+00:00     33.5     67.1                50.0
# 2019-04-09 11:00:00+00:00      NaN      NaN                50.0

# %%
no2.head()
# Out:
#                             city country location parameter  value   unit
# date.utc
# 2019-06-21 00:00:00+00:00  Paris      FR  FR04014       no2   20.0  µg/m³
# 2019-06-20 23:00:00+00:00  Paris      FR  FR04014       no2   21.8  µg/m³
# 2019-06-20 22:00:00+00:00  Paris      FR  FR04014       no2   26.5  µg/m³
# 2019-06-20 21:00:00+00:00  Paris      FR  FR04014       no2   24.9  µg/m³
# 2019-06-20 20:00:00+00:00  Paris      FR  FR04014       no2   21.4  µg/m³

# %%
no2.pivot(columns='location',values='value').plot()
# Out:
# <Axes: xlabel='date.utc'>

# %%
air_quality.pivot_table(values='value',index='location',columns='parameter',aggfunc='mean')
# Out:
# parameter                 no2       pm25
# location
# BETR801             26.950920  23.169492
# FR04014             29.374284        NaN
# London Westminster  29.740050  13.443568

# %%
air_quality.pivot_table(
    values='value',
    index='location',
    columns='parameter',
    aggfunc='mean',
    margins = True,
)
# Out:
# parameter                 no2       pm25        All
# location
# BETR801             26.950920  23.169492  24.982353
# FR04014             29.374284        NaN  29.374284
# London Westminster  29.740050  13.443568  21.491708
# All                 29.430316  14.386849  24.222743

# %%
air_quality.groupby(["parameter", "location"])[["value"]].mean()
# Out:
#                                   value
# parameter location
# no2       BETR801             26.950920
#           FR04014             29.374284
#           London Westminster  29.740050
# pm25      BETR801             23.169492
#           London Westminster  13.443568

# %%
no2_pivoted = no2.pivot(columns='location', values = 'value').reset_index()
no2_pivoted.head()
# Out:
# location                  date.utc  BETR801  FR04014  London Westminster
# 0        2019-04-09 01:00:00+00:00     22.5     24.4                 NaN
# 1        2019-04-09 02:00:00+00:00     53.5     27.4                67.0
# 2        2019-04-09 03:00:00+00:00     54.5     34.2                67.0
# 3        2019-04-09 04:00:00+00:00     34.5     48.5                41.0
# 4        2019-04-09 05:00:00+00:00     46.5     59.5                41.0

# %%
no_2 = no2_pivoted.melt(id_vars='date.utc')
no_2.head()
# Out:
#                    date.utc location  value
# 0 2019-04-09 01:00:00+00:00  BETR801   22.5
# 1 2019-04-09 02:00:00+00:00  BETR801   53.5
# 2 2019-04-09 03:00:00+00:00  BETR801   54.5
# 3 2019-04-09 04:00:00+00:00  BETR801   34.5
# 4 2019-04-09 05:00:00+00:00  BETR801   46.5

# %%
no_2 = no2_pivoted.melt(
    id_vars='date.utc',
    value_vars=['BETR801','FR04014','London Westminster'],
    value_name='NO_2',
    var_name='id_location')
no_2.head()
# Out:
#                    date.utc id_location  NO_2
# 0 2019-04-09 01:00:00+00:00     BETR801  22.5
# 1 2019-04-09 02:00:00+00:00     BETR801  53.5
# 2 2019-04-09 03:00:00+00:00     BETR801  54.5
# 3 2019-04-09 04:00:00+00:00     BETR801  34.5
# 4 2019-04-09 05:00:00+00:00     BETR801  46.5

# %%
df1 = pd.DataFrame({
    'employee':['Bob','Jake','Lisa','Sue'],
    'group':["Accounting",'Engineering','Engineering',"HR"]
})

df2 = pd.DataFrame({
    'employee':['Lisa','Bob','Jake','Sue'],
    'hire_date':[2004,2008,2011,2009]
})
print(df1);
print('-'*20);
print(df2)
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
# --------------------
#   employee  hire_date
# 0     Lisa       2004
# 1      Bob       2008
# 2     Jake       2011
# 3      Sue       2009

# %%
df3 = pd.merge(df1,df2)
df3
# Out:
#   employee        group  hire_date
# 0      Bob   Accounting       2008
# 1     Jake  Engineering       2011
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2009

# %%
df4 = pd.DataFrame({
    'group':['Accounting','Engineering','HR'],
    'supervisor':['Carly','Guido','Steve'
    ]
})

print(df3);print('-'*20);print(df4)
# Out:
#   employee        group  hire_date
# 0      Bob   Accounting       2008
# 1     Jake  Engineering       2011
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2009
# --------------------
#          group supervisor
# 0   Accounting      Carly
# 1  Engineering      Guido
# 2           HR      Steve

# %%
pd.merge(df3,df4)
# Out:
#   employee        group  hire_date supervisor
# 0      Bob   Accounting       2008      Carly
# 1     Jake  Engineering       2011      Guido
# 2     Lisa  Engineering       2004      Guido
# 3      Sue           HR       2009      Steve

# %%
pd.merge(df4,df3)
# Out:
#          group supervisor employee  hire_date
# 0   Accounting      Carly      Bob       2008
# 1  Engineering      Guido     Jake       2011
# 2  Engineering      Guido     Lisa       2004
# 3           HR      Steve      Sue       2009

# %%
df5 = pd.DataFrame({
    'group':['Accounting',"Accounting",'Engineering','Engineering','HR','HR'],
    'skills':['math','spreadsheets','coding','linux','spredsheets','orgnization']
})
print(df1);print("-"*20);print(df5)
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
# --------------------
#          group        skills
# 0   Accounting          math
# 1   Accounting  spreadsheets
# 2  Engineering        coding
# 3  Engineering         linux
# 4           HR   spredsheets
# 5           HR   orgnization

# %%
pd.merge(df1,df5)
# Out:
#   employee        group        skills
# 0      Bob   Accounting          math
# 1      Bob   Accounting  spreadsheets
# 2     Jake  Engineering        coding
# 3     Jake  Engineering         linux
# 4     Lisa  Engineering        coding
# 5     Lisa  Engineering         linux
# 6      Sue           HR   spredsheets
# 7      Sue           HR   orgnization

# %%
pd.merge(df1,df2, on='employee')
# Out:
#   employee        group  hire_date
# 0      Bob   Accounting       2008
# 1     Jake  Engineering       2011
# 2     Lisa  Engineering       2004
# 3      Sue           HR       2009

# %%
df6 = pd.DataFrame({
    'name':['Bob','Jake','Lisa','Sue'],
    'salary':[7000,8000,12000,9000]
})
print(df1);
print('-'*20);
print(df6)
# Out:
#   employee        group
# 0      Bob   Accounting
# 1     Jake  Engineering
# 2     Lisa  Engineering
# 3      Sue           HR
# --------------------
#    name  salary
# 0   Bob    7000
# 1  Jake    8000
# 2  Lisa   12000
# 3   Sue    9000

# %%
pd.merge(df1,df6,left_on='employee',right_on='name')
# Out:
#   employee        group  name  salary
# 0      Bob   Accounting   Bob    7000
# 1     Jake  Engineering  Jake    8000
# 2     Lisa  Engineering  Lisa   12000
# 3      Sue           HR   Sue    9000

# %%
pd.merge(df1,df6,left_on='employee',right_on='name').drop('name',axis=1) #important
# Out:
#   employee        group  salary
# 0      Bob   Accounting    7000
# 1     Jake  Engineering    8000
# 2     Lisa  Engineering   12000
# 3      Sue           HR    9000

# %%
df1a =df1.set_index('employee') #settint hte employee columna as explict
df2a=df2.set_index('employee')
print(df1a);print('-'*22);print(df2a)
# Out:
#                 group
# employee
# Bob        Accounting
# Jake      Engineering
# Lisa      Engineering
# Sue                HR
# ----------------------
#           hire_date
# employee
# Lisa           2004
# Bob            2008
# Jake           2011
# Sue            2009

# %%
df1a.join(df2a)
# Out:
#                 group  hire_date
# employee
# Bob        Accounting       2008
# Jake      Engineering       2011
# Lisa      Engineering       2004
# Sue                HR       2009

# %%
df7 = pd.DataFrame({
    'name':['Peter','Paul','Mary'],
    'food':['fish','beans','bread']},
    columns = ['name','food']

)

df8 = pd.DataFrame({
    'name':['Mary','Joseph'],
    'drink':['wine','beer']},
    columns = ['name','drink']
)

print(df7);
print('-'*33);
print(df8)
# Out:
#     name   food
# 0  Peter   fish
# 1   Paul  beans
# 2   Mary  bread
# ---------------------------------
#      name drink
# 0    Mary  wine
# 1  Joseph  beer

# %%
pd.merge(df7,df8)
# Out:
#    name   food drink
# 0  Mary  bread  wine

# %%
pd.merge(df7,df8,how='inner')
# Out:
#    name   food drink
# 0  Mary  bread  wine

# %%
pd.merge(df7,df8,how='outer')
# Out:
#      name   food drink
# 0   Peter   fish   NaN
# 1    Paul  beans   NaN
# 2    Mary  bread  wine
# 3  Joseph    NaN  beer

# %%
pd.merge(df7,df8,how='left')
# Out:
#     name   food drink
# 0  Peter   fish   NaN
# 1   Paul  beans   NaN
# 2   Mary  bread  wine

# %%
pd.merge(df7,df8,how='right')
# Out:
#      name   food drink
# 0    Mary  bread  wine
# 1  Joseph    NaN  beer

# %%
df9 = pd.DataFrame({
    'name':['Bob','Jake','Lisa','Sue'],
    'rank':[1,2,3,4]
})

df10 = pd.DataFrame({
    'name':['Bob','Jake','Lisa','Sue'],
    'rank':[3,1,4,2]
})
print(df9);
print('-'*22);
print(df10)
# Out:
#    name  rank
# 0   Bob     1
# 1  Jake     2
# 2  Lisa     3
# 3   Sue     4
# ----------------------
#    name  rank
# 0   Bob     3
# 1  Jake     1
# 2  Lisa     4
# 3   Sue     2

# %%
pd.merge(df9,df10,on='name')
# Out:
#    name  rank_x  rank_y
# 0   Bob       1       3
# 1  Jake       2       1
# 2  Lisa       3       4
# 3   Sue       4       2

# %%
pd.merge(df9,df10,on='rank')
# Out:
#   name_x  rank name_y
# 0    Bob     1   Jake
# 1   Jake     2    Sue
# 2   Lisa     3    Bob
# 3    Sue     4   Lisa

# %%
pd.merge(df9,df10,on='name',suffixes =['_left','_Right'])
# Out:
#    name  rank_left  rank_Right
# 0   Bob          1           3
# 1  Jake          2           1
# 2  Lisa          3           4
# 3   Sue          4           2

# %%
import numpy as np
vals2 = np.array([1,np.nan,3,4])
vals2.dtype
# Out:
# dtype('float64')

# %%
1 + np.nan
# Out:
# nan

# %%
vals2.sum()
# Out:
# nan

# %%
vals2.min() , vals2.max()
# Out:
# (nan, nan)

# %%
np.nansum(vals2), np.nanmin(vals2),np.nanmax(vals2) #safe mode . it will ignores all the nan values
# Out:
# (8.0, 1.0, 4.0)

# %%
data = pd.Series([1,np.nan,'hello',None])

# %%
data
# Out:
# 0        1
# 1      NaN
# 2    hello
# 3     None
# dtype: object

# %%
data.isnull() #retures a boolen mask over the data
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
data[data.isnull()]
# Out:
# 1     NaN
# 3    None
# dtype: object

# %%
data.notnull()
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
data[data.notnull()] # boollen mask retured by notnull() in series indes
# Out:
# 0        1
# 2    hello
# dtype: object

# %%
data.dropna() # removes the Na values
# Out:
# 0        1
# 2    hello
# dtype: object

# %%
data
# Out:
# 0        1
# 1      NaN
# 2    hello
# 3     None
# dtype: object

# %%
df = pd.DataFrame([[1, np.nan, 2],
                  [2, 3, 5],
                  [np.nan, 4,6]])
df
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6

# %%
df.dropna() # removes the entire row
# Out:
#      0    1  2
# 1  2.0  3.0  5

# %%
df.dropna(axis = 1)
# Out:
#    2
# 0  2
# 1  5
# 2  6

# %%
df[3] = np.nan
df
# Out:
#      0    1  2   3
# 0  1.0  NaN  2 NaN
# 1  2.0  3.0  5 NaN
# 2  NaN  4.0  6 NaN

# %%
df.dropna(axis = 1, how = 'all') #drops columns with all null values
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6

# %%
df.dropna(axis = 0 , thresh = 3)  # keep only rows with a minimum of 3 non-null␣,→values
# Out:
#      0    1  2   3
# 1  2.0  3.0  5 NaN

# %%
data = pd.Series([1,np.nan,2,None,3],index = list('abcde'))
data
# Out:
# a    1.0
# b    NaN
# c    2.0
# d    NaN
# e    3.0
# dtype: float64

# %%
data.fillna(0)
# Out:
# a    1.0
# b    0.0
# c    2.0
# d    0.0
# e    3.0
# dtype: float64

# %%
data.fillna(method='ffill') #forward the previous value before nan
# Out:
# a    1.0
# b    1.0
# c    2.0
# d    2.0
# e    3.0
# dtype: float64

# %%
data.fillna(method='bfill')
# Out:
# a    1.0
# b    2.0
# c    2.0
# d    3.0
# e    3.0
# dtype: float64

# %%
df
# Out:
#      0    1  2   3
# 0  1.0  NaN  2 NaN
# 1  2.0  3.0  5 NaN
# 2  NaN  4.0  6 NaN

# %%
df.fillna(method = 'ffill', axis = 1)
# Out:
#      0    1    2    3
# 0  1.0  1.0  2.0  2.0
# 1  2.0  3.0  5.0  5.0
# 2  NaN  4.0  6.0  6.0

# %%
titanic = pd.read_csv('titanic/tested.csv')

# %%
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
titanic['Name'].str.lower()
# Out:
# 0                                  kelly, mr. james
# 1                  wilkes, mrs. james (ellen needs)
# 2                         myles, mr. thomas francis
# 3                                  wirz, mr. albert
# 4      hirvonen, mrs. alexander (helga e lindqvist)
#                            ...
# 413                              spector, mr. woolf
# 414                    oliva y ocana, dona. fermina
# 415                    saether, mr. simon sivertsen
# 416                             ware, mr. frederick
# 417                        peter, master. michael j
# Name: Name, Length: 418, dtype: object

# %%
"Name" in titanic.columns
# Out:
# True

# %%
titanic["Name"][:5]
# Out:
# 0                                Kelly, Mr. James
# 1                Wilkes, Mrs. James (Ellen Needs)
# 2                       Myles, Mr. Thomas Francis
# 3                                Wirz, Mr. Albert
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# Name: Name, dtype: object

# %%
titanic['Name'].str.split(',')
# Out:
# 0                                  [Kelly,  Mr. James]
# 1                  [Wilkes,  Mrs. James (Ellen Needs)]
# 2                         [Myles,  Mr. Thomas Francis]
# 3                                  [Wirz,  Mr. Albert]
# 4      [Hirvonen,  Mrs. Alexander (Helga E Lindqvist)]
#                             ...
# 413                              [Spector,  Mr. Woolf]
# 414                    [Oliva y Ocana,  Dona. Fermina]
# 415                    [Saether,  Mr. Simon Sivertsen]
# 416                             [Ware,  Mr. Frederick]
# 417                        [Peter,  Master. Michael J]
# Name: Name, Length: 418, dtype: object

# %%
titanic['Surname'] = titanic['Name'].str.split(',').str.get(1)
titanic['Surname']
# Out:
# 0                                Mr. James
# 1                 Mrs. James (Ellen Needs)
# 2                       Mr. Thomas Francis
# 3                               Mr. Albert
# 4       Mrs. Alexander (Helga E Lindqvist)
#                       ...
# 413                              Mr. Woolf
# 414                          Dona. Fermina
# 415                    Mr. Simon Sivertsen
# 416                          Mr. Frederick
# 417                      Master. Michael J
# Name: Surname, Length: 418, dtype: object

# %%
titanic['Name'].str.contains('Ware')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416     True
# 417    False
# Name: Name, Length: 418, dtype: bool

# %%
titanic[titanic['Name'].str.contains('Ware')]
# Out:
#      PassengerId  Survived  Pclass  \
# 278         1170         0       2
# 362         1254         1       2
# 406         1298         0       2
# 416         1308         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 278                          Ware, Mr. John James    male  30.0      1      0
# 362  Ware, Mrs. John James (Florence Louise Long)  female  31.0      0      0
# 406                     Ware, Mr. William Jeffery    male  23.0      1      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
#
#        Ticket   Fare Cabin Embarked                                  Surname
# 278  CA 31352  21.00   NaN        S                           Mr. John James
# 362  CA 31352  21.00   NaN        S   Mrs. John James (Florence Louise Long)
# 406     28666  10.50   NaN        S                      Mr. William Jeffery
# 416    359309   8.05   NaN        S                            Mr. Frederick

# %%
titanic['Name'].str.len()
# Out:
# 0      16
# 1      32
# 2      25
# 3      16
# 4      44
#        ..
# 413    18
# 414    28
# 415    28
# 416    19
# 417    24
# Name: Name, Length: 418, dtype: int64

# %%
titanic['Name'].str.len().idxmax()
# Out:
# 343

# %%
titanic.loc[titanic['Name'].str.len().idxmax(),'Name']
# Out:
# 'Cardeza, Mrs. James Warburton Martinez (Charlotte Wardle Drake)'

# %%
titanic['Sex_short'] = titanic['Sex'].replace({'male':'M','female':'F'})
titanic['Sex_short']
# Out:
# 0      M
# 1      F
# 2      M
# 3      M
# 4      F
#       ..
# 413    M
# 414    F
# 415    M
# 416    M
# 417    M
# Name: Sex_short, Length: 418, dtype: object
