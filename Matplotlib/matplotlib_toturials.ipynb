# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots()
ax.plot([1,2,3,4],[1,4,2,3])
plt.show()

# %%
np.random.seed(19680801)  # seed the random number generator.
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b',c='c', s='d',data = data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')

# %%
x = np.linspace(0, 2, 100)  # Sample data.

# Note that even in the OO-style, we use `.pyplot.figure` to create the Figure.
fig, ax = plt.subplots(figsize=(5, 3), layout='constrained')
ax.plot(x, x, label='linear')  # Plot some data on the Axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the Axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x_label')  # Add an x-label to the Axes.
ax.set_ylabel('y_label')  # Add a y-label to the Axes.
ax.set_title("hARRY'S Plot")  # Add a title to the Axes.
ax.legend()  # Add a legend.

# %%
x = np.linspace(0, 2, 100)  # Sample data.

plt.figure(figsize=(5, 2.7), layout='constrained')
plt.plot(x, x, label='linear')  # Plot some data on the (implicit) Axes.
plt.plot(x, x**2, label='quadratic')  # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()

# %%
def my_plotter(ax, data1, data2, param_dict):
    """
    A helper function to make a graph.
    """
    out = ax.plot(data1, data2, **param_dict)
    return out

# %%
data1, data2, data3, data4 = np.random.randn(4, 100)  # make 4 random data sets
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(5, 2.7))
my_plotter(ax1, data1, data2, {'marker': 'x'})
my_plotter(ax2, data3, data4, {'marker': 'o'})

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
x = np.arange(len(data1))
ax.plot(x, np.cumsum(data1), color='blue', linewidth=3, linestyle='--')
l, = ax.plot(x, np.cumsum(data2), color='orange', linewidth=2)
l.set_linestyle(':')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("iris_dataset/iris.csv")

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# line plot :

# %%
plt.figure(figsize=(10,5))
plt.plot(data['petal_length'],label = 'Petal Length')
plt.plot(data['petal_width'],label = 'Petal Width')
plt.title("Petal Length and Width")
plt.xlabel("Index")
plt.ylabel("Length/Width")
plt.legend()
plt.show()

# %% [markdown]
# scatter plot : used to obseve the relationship between two numeric variables

# %%
plt.figure(figsize=(10,5))
plt.scatter(data['petal_length'],data['petal_width'],color = 'green')
plt.title("Scatter plot of petal length vs width")
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.show()

# %% [markdown]
# Historgam helps in understandin the ddistrubution of numeric data

# %%
plt.figure(figsize=(10,5))
plt.hist(data['petal_length'],bins=10,color='purple',alpha = 0.5)
plt.title("Distrubution of Petal Length")
plt.xlabel("Petal Length")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# bar plot these are great for categorial data

# %%
species_count = data['species'].value_counts()
plt.figure(figsize=(10,5))
species_count.plot(kind='bar',color=['blue','orange','green'])
plt.title("Species Counts")
plt.xlabel("Species")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# box plot shows the spread and outliers in the data

# %%
plt.figure(figsize=(10,5))
data.boxplot(column='petal_length',by='species')
plt.title("Boxplot of petal length by species")
plt.suptitle('')
plt.xlabel("Species")
plt.ylabel("Petal Length")
plt.show()

# %% [markdown]
# p

# %%
plt.figure(figsize=(10,5))
species_count.plot(kind='pie',autopct='%1.1f%%',startangle=140)
plt.title("Specices Distribution")
#plt.xlabel("")
plt.ylabel("")
plt.show()

# %% [markdown]
# heat map is used to show the relationships or correlations among multiple variables

# %%
import seaborn as sns
corr = data.corr()
plt.figure(figsize=(8,6))
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.title("correlation Matrix")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 import seaborn as sns
# ----> 2 corr = data.corr()
#       3 plt.figure(figsize=(8,6))
#       4 sns.heatmap(corr,annot=True,cmap='coolwarm')
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %% [markdown]
# annotate adding

# %%
plt.figure(figsize=(10,5))
plt.scatter(data['petal_length'],data['petal_width'],color = 'blue')
for i in range(len(data)):
    plt.text(data['petal_length'][i],data['petal_width'][i],data['species'][i]
            , fontsize = 8,ha='right')
    
plt.title("Scatter plot with annotations")
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.show()

# %% [markdown]
# sub plots

# %%
plt.figure(figsize=(15, 10))
# First subplot - Line plot
plt.subplot(2, 2, 1)
plt.plot(data['petal_length'], color='green')
plt.title("Line Plot of Petal Length")
# Secnd subplot - Histogram
plt.subplot(2, 2, 2)
plt.hist(data['petal_width'], bins=15, color='orange')
plt.title("Histogram of Petal Width")
# Third subplot - Box plot
plt.subplot(2, 2, 3)
data.boxplot(column='sepal_length', by='species')
plt.title("Boxplot of Sepal Length by Species")
plt.suptitle('')  # Suppresses the default title
# Fourth subplot - Scatter plot
plt.subplot(3, 3, 4)
plt.scatter(data['sepal_length'], data['sepal_width'], color='purple')
plt.title("Scatter Plot of Sepal Length vs Width")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_13836/1824234964.py:16: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3, 3, 4)
