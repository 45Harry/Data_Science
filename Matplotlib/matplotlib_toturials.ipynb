# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots()
ax.plot([1,2,3,4],[1,4,2,3])
plt.show()

# %%
np.random.seed(19680801)  # seed the random number generator.
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b',c='c', s='d',data = data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')

# %%
x = np.linspace(0, 2, 100)  # Sample data.

# Note that even in the OO-style, we use `.pyplot.figure` to create the Figure.
fig, ax = plt.subplots(figsize=(5, 3), layout='constrained')
ax.plot(x, x, label='linear')  # Plot some data on the Axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the Axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x_label')  # Add an x-label to the Axes.
ax.set_ylabel('y_label')  # Add a y-label to the Axes.
ax.set_title("hARRY'S Plot")  # Add a title to the Axes.
ax.legend()  # Add a legend.

# %%
x = np.linspace(0, 2, 100)  # Sample data.

plt.figure(figsize=(5, 2.7), layout='constrained')
plt.plot(x, x, label='linear')  # Plot some data on the (implicit) Axes.
plt.plot(x, x**2, label='quadratic')  # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()

# %%
def my_plotter(ax, data1, data2, param_dict):
    """
    A helper function to make a graph.
    """
    out = ax.plot(data1, data2, **param_dict)
    return out

# %%
data1, data2, data3, data4 = np.random.randn(4, 100)  # make 4 random data sets
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(5, 2.7))
my_plotter(ax1, data1, data2, {'marker': 'x'})
my_plotter(ax2, data3, data4, {'marker': 'o'})

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
x = np.arange(len(data1))
ax.plot(x, np.cumsum(data1), color='blue', linewidth=3, linestyle='--')
l, = ax.plot(x, np.cumsum(data2), color='orange', linewidth=2)
l.set_linestyle(':')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("iris_dataset/iris.csv")

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# line plot :

# %%
plt.figure(figsize=(10,5))
plt.plot(data['petal_length'],label = 'Petal Length')
plt.plot(data['petal_width'],label = 'Petal Width')
plt.title("Petal Length and Width")
plt.xlabel("Index")
plt.ylabel("Length/Width")
plt.legend()
plt.show()

# %% [markdown]
# scatter plot : used to obseve the relationship between two numeric variables

# %%
plt.figure(figsize=(10,5))
plt.scatter(data['petal_length'],data['petal_width'],color = 'green')
plt.title("Scatter plot of petal length vs width")
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.show()

# %% [markdown]
# Historgam helps in understandin the ddistrubution of numeric data

# %%
plt.figure(figsize=(10,5))
plt.hist(data['petal_length'],bins=10,color='purple',alpha = 0.5)
plt.title("Distrubution of Petal Length")
plt.xlabel("Petal Length")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# bar plot these are great for categorial data

# %%
species_count = data['species'].value_counts()
plt.figure(figsize=(10,5))
species_count.plot(kind='bar',color=['blue','orange','green'])
plt.title("Species Counts")
plt.xlabel("Species")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# box plot shows the spread and outliers in the data

# %%
plt.figure(figsize=(10,5))
data.boxplot(column='petal_length',by='species')
plt.title("Boxplot of petal length by species")
plt.suptitle('')
plt.xlabel("Species")
plt.ylabel("Petal Length")
plt.show()

# %% [markdown]
# p

# %%
plt.figure(figsize=(10,5))
species_count.plot(kind='pie',autopct='%1.1f%%',startangle=140)
plt.title("Specices Distribution")
#plt.xlabel("")
plt.ylabel("")
plt.show()

# %% [markdown]
# heat map is used to show the relationships or correlations among multiple variables

# %% [markdown]
# import seaborn as sns
# corr = data.corr()
# plt.figure(figsize=(8,6))
# sns.heatmap(corr,annot=True,cmap='coolwarm')
# plt.title("correlation Matrix")
# plt.show()

# %% [markdown]
# annotate adding

# %%
plt.figure(figsize=(10,5))
plt.scatter(data['petal_length'],data['petal_width'],color = 'blue')
for i in range(len(data)):
    plt.text(data['petal_length'][i],data['petal_width'][i],data['species'][i]
            , fontsize = 8,ha='right')
    
plt.title("Scatter plot with annotations")
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.show()

# %% [markdown]
# sub plots

# %%
plt.figure(figsize=(18, 14))
# First subplot - Line plot
plt.subplot(2, 2, 1)
plt.plot(data['petal_length'], color='green')
plt.title("Line Plot of Petal Length")
# Secnd subplot - Histogram
plt.subplot(2, 2, 2)
plt.hist(data['petal_width'], bins=15, color='orange')
plt.title("Histogram of Petal Width")
# Third subplot - Box plot
plt.subplot(2,2,3)
data.boxplot(column='sepal_length', by='species')
plt.title("Boxplot of Sepal Length by Species")
# Fourth subplot - Scatter plot

plt.subplot(2,2,4)
plt.scatter(data['sepal_length'], data['sepal_width'], color='purple')
plt.title("Scatter Plot of Sepal Length vs Width") 

plt.suptitle('')  # Suppresses the default title
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_12013/3346345316.py:16: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2,2,4)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18, 14))

# First subplot - Line plot
plt.subplot(2, 2, 1)
plt.plot(data['petal_length'], color='green')
plt.title("Line Plot of Petal Length")

# Secnd subplot - Histogram
plt.subplot(2, 2, 2)
plt.hist(data['petal_width'], bins=15, color='orange')
plt.title("Histogram of Petal Width")

# Third subplot - Box plot
plt.subplot(2, 2, 3)  # Explicitly create the subplot
plt.boxplot(data['sepal_length'] )
plt.title("Boxplot of Sepal Length by Species")

# Fourth subplot - Scatter plot
plt.subplot(2, 2, 4)
plt.scatter(data['sepal_length'], data['sepal_width'], color='purple')
plt.title("Scatter Plot of Sepal Length vs Width")

plt.suptitle('')
plt.tight_layout()
plt.show()

# %%
plt.savefig("plot_example.jpg",dpi=300)

# %% [markdown]
# advanced plotting outline

# %%
plt.figure(figsize=(10, 6)) 
# Adding diﬀerent styles and markers 
plt.plot(data['petal_length'], label='Petal Length', linestyle='-', marker='o', color='steelblue', linewidth=1.5) 
plt.plot(data['petal_width'], label='Petal Width', linestyle='--', marker='s', color='firebrick', linewidth=1.5) 
plt.plot(data['sepal_length'], label='Sepal Length', linestyle=':', marker='^', color='darkgreen', linewidth=1.5) 
plt.title("Enhanced Line Plot of Iris Dimensions") 
plt.xlabel("Index") 
plt.ylabel("Measurement (cm)") 
plt.legend() 
plt.grid(which='both', linestyle='--', linewidth=0.5) 
plt.show()
plt.savefig("plot_example.jpg",dpi=300)

# %%
plt.figure(figsize=(10, 6)) 
# Use colormap to represent petal length 
scatter = plt.scatter( 
    data['sepal_length'], 
    data['sepal_width'], 
    c=data['petal_length'], 
    cmap='viridis', 
    s=data['petal_width'] * 50,  # Scale size based on petal width 
    alpha=0.7, 
    edgecolor='k' 
) 
plt.colorbar(scatter, label='Petal Length') 
plt.title("Styled Scatter Plot of Sepal Dimensions with Petal Characteristics") 
plt.xlabel("Sepal Length") 
plt.ylabel("Sepal Width") 
plt.grid(True)

# %%
# Filter data by species 
setosa = data[data['species'] == 'setosa'] 
versicolor = data[data['species'] == 'versicolor'] 
virginica = data[data['species'] == 'virginica'] 
# Plot stacked histogram for sepal lengths 
plt.figure(figsize=(10, 6)) 
plt.hist( 
    [setosa['sepal_length'], versicolor['sepal_length'], virginica['sepal_length']], 
    bins=15, 
    stacked=True, 
    color=['#FF9999', '#66B2FF', '#99FF99'], 
    label=['Setosa', 'Versicolor', 'Virginica'] 
) 
plt.title("Stacked Histogram of Sepal Length by Species") 
plt.xlabel("Sepal Length (cm)") 
plt.ylabel("Frequency") 
plt.legend() 
plt.grid(axis='y', linestyle='--', linewidth=0.5) 
plt.show()

# %%
plt.figure(figsize=(10, 6)) 
# Density plot for petal length across species 
sns.kdeplot(data=setosa['petal_length'], label="Setosa", fill=True, color='#FF9999') 
sns.kdeplot(data=versicolor['petal_length'], label="Versicolor", fill=True, color='#66B2FF') 
sns.kdeplot(data=virginica['petal_length'], label="Virginica", fill=True, color='#99FF99') 
plt.title("Density Plot of Petal Length by Species") 
plt.xlabel("Petal Length (cm)") 
plt.ylabel("Density") 
plt.legend() 
plt.grid() 
plt.show()

# %%
plt.figure(figsize=(10, 6)) 
# Custom boxplot for sepal width across species 
sns.boxplot(data=data, x='species', y='sepal_width', notch=True, palette='Pastel1', width=0.6) 
plt.title("Customized Box Plot of Sepal Width by Species") 
plt.xlabel("Species") 
plt.ylabel("Sepal Width (cm)") 
plt.grid(axis='y', linestyle='--') 
plt.show()
# Out:
# /tmp/ipykernel_12013/2349777937.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=data, x='species', y='sepal_width', notch=True, palette='Pastel1', width=0.6)

# %%
plt.figure(figsize=(8, 5)) 
plt.plot(data['petal_length'], color='blue') 
# Change background color 
plt.gca().set_facecolor('#F5F5F5') 
# Customize grid lines 
plt.grid(color='gray', linestyle='-', linewidth=0.2) 
# Add title with specific font properties 
plt.title("Petal Length with Custom Background and Grid", fontsize=14, fontweight='bold', color='darkblue') 
plt.xlabel("Index") 
plt.ylabel("Petal Length (cm)") 
plt.tight_layout()  # Adjust spacing between subplots

# Save the figure BEFORE showing it
plt.savefig("advanced_plot_example.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd  # Assuming you're using pandas for your data

# Load your data (replace 'your_data.csv' with your actual file)
data = pd.read_csv('iris_dataset/iris.csv')

#plt.figure(figsize=(15, 10))
plt.subplots(3,1,figsize=(12,12))

# First subplot - Line plot
plt.subplot(2, 2, 1)
plt.plot(data['petal_length'], color='green')
plt.title("Line Plot of Petal Length")

# Second subplot - Histogram
plt.subplot(2, 2, 2)
plt.hist(data['petal_width'], bins=15, color='orange')
plt.title("Histogram of Petal Width")

# Third subplot - Box plot
plt.subplot(2, 2, 3)
data.boxplot(column='sepal_length', by='species')
plt.title("Boxplot of Sepal Length by Species")
plt.suptitle('')  # Suppresses the default title

# Fourth subplot - Scatter plot
plt.subplot(2, 2, 4)
plt.scatter(data['sepal_length'], data['sepal_width'], color='purple')
plt.title("Scatter Plot of Sepal Length vs Width")

plt.tight_layout()  # Adjust spacing between subplots

# Save the figure BEFORE showing it
plt.savefig("advanced_plot_example.png", dpi=300, bbox_inches='tight')

# Show the plot (optional)
plt.show()
# Out:
# /tmp/ipykernel_12013/687156565.py:11: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 2, 1)
# /tmp/ipykernel_12013/687156565.py:21: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 2, 3)
# /tmp/ipykernel_12013/687156565.py:27: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2, 2, 4)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data= pd.read_csv('titanic/tested.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
plt.figure(figsize=(10,5))
plt.plot(data['Age'], label = 'Pessenger Age')
plt.title('Passenger Age')
plt.ylabel("Age")
plt.xlabel("No. Passenger")
plt.savefig("titanic_figs/linegraph.png")
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.scatter(data['Age'],data['Pclass'],color = 'green')
plt.title('Scatter plot of Passenger Age')
plt.ylabel("Pclass")
plt.xlabel('Passenger Age')
plt.savefig("titanic_figs/Scatterplt.png")
plt.show()

# %%
df_original = pd.read_csv("wine_data/winemag-data_first150k.csv")

# %%
df_original.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
df_original.shape
# Out:
# (150930, 11)

# %%
df_original['country'].value_counts().head(15).plot.bar()
# Out:
# <Axes: xlabel='country'>

# %%
df_original['points'].value_counts().sort_index().plot.bar()
# Out:
# <Axes: xlabel='points'>

# %%
#plot price
df_original['price'].value_counts().sort_index().plot.line()
# Out:
# <Axes: xlabel='price'>

# %%
df_original['points'].value_counts().sort_index().plot.area()
# Out:
# <Axes: xlabel='points'>

# %%
df_original.plot.scatter(x='points', y  ='price')
# Out:
# <Axes: xlabel='points', ylabel='price'>

# %%
df_original.plot.hexbin(x='price',y='points')
# Out:
# <Axes: xlabel='price', ylabel='points'>

# %%
df_original['points'].value_counts().sort_index().plot.bar(figsize = (10,5),fontsize = 14, title = 'Count of Wine-Points')
# Out:
# <Axes: title={'center': 'Count of Wine-Points'}, xlabel='points'>

# %%
#adjusting title fontsize uinsg matplotlib
import matplotlib as mlt

ax = df_original['points'].value_counts().sort_index().plot.bar(
    figsize = (12,6),
    fontsize = 14)
ax.set_title("Count the Wine-Points", fontsize = 20 )
ax.set_xlabel("Points",fontsize = 20)
ax.set_ylabel("Count", fontsize = 20)
# Out:
# Text(0, 0.5, 'Count')

# %%
#Creating a frame of rows and columns to place the plots
fig, axi = plt.subplots(4,1, figsize = (12,12))
#plot1
df_original['points'].value_counts().plot.bar(
    ax = axi[0],
    fontsize = 14    
)
axi[0].set_title("Count points of Wine", fontsize = 20)
#Plot2
df_original['country'].value_counts().head(10).plot.bar(
    ax = axi[1],
    fontsize = 14
)
axi[1].set_title('Country', fontsize = 20)
#plot3
df_original['winery'].value_counts().head().plot.bar(
    ax = axi[2],
    fontsize = 14
)
axi[2].set_title("No of Wines from Winery")
# Out:
# Text(0.5, 1.0, 'No of Wines from Winery')

# %%
df_original.isnull().count()
# Out:
# Unnamed: 0     150930
# country        150930
# description    150930
# designation    150930
# points         150930
# price          150930
# province       150930
# region_1       150930
# region_2       150930
# variety        150930
# winery         150930
# dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(df_original['country'].head(200))
# Out:
# <Axes: xlabel='count', ylabel='country'>

# %%
sns.countplot(df_original['province'].head(20))
# Out:
# <Axes: xlabel='count', ylabel='province'>

# %%
sns.kdeplot(df_original['price'])
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.kdeplot(df_original.query("price<200").price)
ax.set_title("Price of Wine")
# Out:
# Text(0.5, 1.0, 'Price of Wine')

# %%
#KDE 2D plot
sns.kdeplot(df_original[df_original['price']< 200].loc[:,['price', 'points']].dropna().sample(5000))
# Out:
# <Axes: ylabel='Density'>

# %%
ax = sns.distplot(df_original['points'], bins = 20, kde = False)
# Out:
# /tmp/ipykernel_12013/3685506896.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(df_original['points'], bins = 20, kde = False)

# %%
df1= df_original[df_original.variety.isin(df_original.variety.value_counts().head(5).index)]

sns.boxplot(
    x = 'variety',
    y = 'points',
    data = df1
)
# Out:
# <Axes: xlabel='variety', ylabel='points'>
